# %%
import pandas as pd

customer_tickets = r"C:\Users\leibn\Downloads\Customer Support Ticket Dataset\Customer Support Ticket Dataset\customer_support_tickets.csv"
product_sales = r"C:\Users\leibn\Downloads\Product Sales Dataset\Product Sales Dataset\statsfinal.csv"

ct = pd.read_csv(customer_tickets)
ps = pd.read_csv(product_sales)

df_ct = pd.DataFrame(ct)
df_ps = pd.DataFrame(ps)

# %%
df_ct.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %%
df_ps.head()
# Out:
#    Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0           0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1           1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2           2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3           3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4           4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
#
#        S-P3      S-P4
# 0   3121.92   6466.91
# 1  19392.76  11222.62
# 2   3224.90   8163.85
# 3  17018.80  11921.36
# 4  11837.28   5048.04
