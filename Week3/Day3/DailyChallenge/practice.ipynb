# %%
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 6.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------- ----- 8.4/9.6 MB 40.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 35.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------- ----------------------------- 1/4 [statsmodels]
#    ---------- ----------------------------- 1/4 [statsmodels]
# ...
