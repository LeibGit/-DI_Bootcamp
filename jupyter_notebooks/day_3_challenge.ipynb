# %% [markdown]
# <a href="https://colab.research.google.com/github/LeibGit/-DI_Bootcamp/blob/main/day_3_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

mm_scaler = MinMaxScaler()
scaler = StandardScaler()
df = pd.read_csv("datascience_salaries.csv")

numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df_scaled = scaler.fit_transform(df[numeric_cols])

df['salary'] = mm_scaler.fit_transform(df[['salary']])
df.head()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9)
df_pca = pca.fit_transform(df_scaled)
print(df_pca)

# %%
grouped = df.groupby("experience_level")
salary_stats = grouped['salary'].agg(['mean', 'median'])
print(salary_stats)
