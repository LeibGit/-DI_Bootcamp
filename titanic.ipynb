# %% [markdown]
# <a href="https://colab.research.google.com/github/LeibGit/-DI_Bootcamp/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("Mental_Health.csv")
df_2 = pd.read_csv("Sleep.csv")
df_3 = pd.read_csv("Credit.csv")

# %%
df_1.head()

# %%
df_2.head()

# %%
df_3.head()

# %%
df_1.describe()

# %%
df_2.describe()

# %%
df_3.describe()
